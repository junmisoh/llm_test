# %%
import openai
import os
import certifi
import httpx
# from dotenv import load_dotenv

# load_dotenv(override=True)
# amd_api_key = os.environ.get("AMD_API_KEY")

client = openai.OpenAI(
    base_url="https://llm-api.amd.com/OnPrem",
    api_key="dummy",
    http_client=httpx.Client(
        verify=certifi.where()
        ),
    default_headers={
        "Ocp-Apim-Subscription-Key": "a5ab74eb757b4b98989f6393212feb7a",
        "user": os.getlogin()
        }
)

response = client.chat.completions.create(
    model="GPT-oss-20B",
    max_completion_tokens=200,
    temperature=0.7,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "How does AI work?"}
    ]
)

print(response)
# Out:
# ChatCompletion(id='chatcmpl-49585f9b45b353f8cc3bac4c570a6687', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='**In a nutshell:**  \n\nArtificial Intelligence (AI) is a set of computer programs that can perform tasks that normally require human intelligence—like recognizing speech, understanding images, making decisions, or playing chess. The most common way modern AI does this is by *learning* from data, rather than being hand', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[], reasoning='We need to explain how AI works, likely in a general sense. The user asked "How does AI work?" They probably want a general explanation: machine learning, deep learning, training data, models, inference. Might mention algorithms, neural networks, backpropagation, training, hyperparameters, etc. Should be accessible and thorough. We can also give examples: classification, regression, natural language processing, computer vision. Provide a high-level overview, mention data, training, testing, deployment. Provide analogy. Also mention types: symbolic AI, sub-symbolic, neural network. Also mention reinforcement learning. Should be clear. We\'ll produce an answer.'), stop_reason=None, token_ids=None)], created=1778662980, model='openai/gpt-oss-20b', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=200, prompt_tokens=80, total_tokens=280, completion_tokens_details=None, prompt_tokens_details=None), prompt_logprobs=None, prompt_token_ids=None, kv_transfer_params=None)

# %%
from IPython.display import Markdown, display

# %%
print(response.choices[0].message.content)
display(Markdown(response.choices[0].message.content))
# Out:
# **In a nutshell:**
#
# Artificial Intelligence (AI) is a set of computer programs that can perform tasks that normally require human intelligence—like recognizing speech, understanding images, making decisions, or playing chess. The most common way modern AI does this is by *learning* from data, rather than being hand
# **In a nutshell:**
#
# Artificial Intelligence (AI) is a set of computer programs that can perform tasks that normally require human intelligence—like recognizing speech, understanding images, making decisions, or playing chess. The most common way modern AI does this is by *learning* from data, rather than being hand
