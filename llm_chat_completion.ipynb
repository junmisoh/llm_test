# %%
import openai
import os
import certifi
import httpx
from IPython.display import Markdown, display
from dotenv import load_dotenv

load_dotenv(override=True)
amd_api_key = os.environ.get("AMD_API_KEY")

client = openai.OpenAI(
    base_url="https://llm-api.amd.com/OnPrem",
    api_key="dummy",
    http_client=httpx.Client(
        verify=certifi.where()
        ),
    default_headers={
        "Ocp-Apim-Subscription-Key": amd_api_key,
        "user": os.getlogin()
        }
)

response = client.chat.completions.create(
    model="Meta-Llama-4-Maverick-17B",
    # max_completion_tokens=200,
    temperature=0.7,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Write an essay about love"}
    ]
)

print(response)
# Out:
# ChatCompletion(id='chatcmpl-26b67678580e20976cbcc1875b7049bc', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The concept of love is a complex and multifaceted phenomenon that has been a subject of human fascination for centuries. It is a universal emotion that transcends cultures, ages, and backgrounds, and is often considered one of the most powerful and transformative experiences that humans can encounter. Love can take many forms, including romantic love, familial love, platonic love, and self-love, each with its own unique characteristics and expressions.\n\nAt its core, love is a deep and profound emotional connection with another person, place, or thing. It is a feeling that can bring immense joy, comfort, and fulfillment to one's life, and is often associated with strong emotions such as affection, attachment, and devotion. Romantic love, in particular, is a powerful force that can bring people together and inspire them to make sacrifices, take risks, and push beyond their limits. It is a feeling that can be all-consuming, and is often characterized by intense passion, intimacy, and commitment.\n\nOne of the most significant aspects of love is its ability to transform and shape our lives. When we experience love, we are often changed in profound ways, and are inspired to become better versions of ourselves. Love can motivate us to be more compassionate, empathetic, and understanding, and can help us to develop a deeper sense of connection and belonging with others. It can also provide a sense of security and stability, and can be a source of comfort and strength in times of need.\n\nLove is not limited to romantic relationships, however. Familial love, for example, is a deep and abiding bond between family members, and is often characterized by a sense of loyalty, duty, and responsibility. Platonic love, on the other hand, is a deep and non-romantic connection with friends and acquaintances, and is often marked by a sense of camaraderie, shared experience, and mutual support. Self-love, finally, is a critical aspect of overall well-being, and involves cultivating a positive and compassionate relationship with oneself.\n\nDespite its many benefits, love can also be a source of pain and suffering. Heartbreak, rejection, and loss are all potential risks associated with loving others, and can be incredibly difficult to navigate. Moreover, love can be a complex and messy emotion, and is often accompanied by feelings of jealousy, insecurity, and uncertainty. Nevertheless, it is precisely this complexity and risk that makes love so valuable and worthwhile.\n\nIn conclusion, love is a multifaceted and dynamic emotion that plays a vital role in human experience. It is a source of joy, comfort, and transformation, and is essential to our emotional and psychological well-being. Whether it is romantic, familial, platonic, or self-directed, love has the power to shape our lives in profound ways, and is a fundamental aspect of what it means to be human. As such, it is worth cultivating, nurturing, and celebrating in all its forms.", refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[], reasoning_content=None), stop_reason=None)], created=1778663832, model='meta-llama/Llama-4-Maverick-17B-128E-Instruct-FP8', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=587, prompt_tokens=26, total_tokens=613, completion_tokens_details=None, prompt_tokens_details=None), prompt_logprobs=None)

# %%
display(Markdown(response.choices[0].message.content))
# Out:
# The concept of love is a complex and multifaceted phenomenon that has been a subject of human fascination for centuries. It is a universal emotion that transcends cultures, ages, and backgrounds, and is often considered one of the most powerful and transformative experiences that humans can encounter. Love can take many forms, including romantic love, familial love, platonic love, and self-love, each with its own unique characteristics and expressions.
#
# At its core, love is a deep and profound emotional connection with another person, place, or thing. It is a feeling that can bring immense joy, comfort, and fulfillment to one's life, and is often associated with strong emotions such as affection, attachment, and devotion. Romantic love, in particular, is a powerful force that can bring people together and inspire them to make sacrifices, take risks, and push beyond their limits. It is a feeling that can be all-consuming, and is often characterized by intense passion, intimacy, and commitment.
#
# One of the most significant aspects of love is its ability to transform and shape our lives. When we experience love, we are often changed in profound ways, and are inspired to become better versions of ourselves. Love can motivate us to be more compassionate, empathetic, and understanding, and can help us to develop a deeper sense of connection and belonging with others. It can also provide a sense of security and stability, and can be a source of comfort and strength in times of need.
#
# Love is not limited to romantic relationships, however. Familial love, for example, is a deep and abiding bond between family members, and is often characterized by a sense of loyalty, duty, and responsibility. Platonic love, on the other hand, is a deep and non-romantic connection with friends and acquaintances, and is often marked by a sense of camaraderie, shared experience, and mutual support. Self-love, finally, is a critical aspect of overall well-being, and involves cultivating a positive and compassionate relationship with oneself.
#
# Despite its many benefits, love can also be a source of pain and suffering. Heartbreak, rejection, and loss are all potential risks associated with loving others, and can be incredibly difficult to navigate. Moreover, love can be a complex and messy emotion, and is often accompanied by feelings of jealousy, insecurity, and uncertainty. Nevertheless, it is precisely this complexity and risk that makes love so valuable and worthwhile.
#
# In conclusion, love is a multifaceted and dynamic emotion that plays a vital role in human experience. It is a source of joy, comfort, and transformation, and is essential to our emotional and psychological well-being. Whether it is romantic, familial, platonic, or self-directed, love has the power to shape our lives in profound ways, and is a fundamental aspect of what it means to be human. As such, it is worth cultivating, nurturing, and celebrating in all its forms.
